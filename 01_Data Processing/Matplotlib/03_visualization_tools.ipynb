# %% [markdown]
# ## Bar Charts

# %%
import matplotlib.pyplot as plt

# %%
product = ['A','B','C','D']
sales = [1000,1500,800,1200] 

plt.bar(product,sales,color='orange',label='Sales data 2025')
plt.title("Product Sales Comparison")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.legend()

# %% [markdown]
# ## Pie Chart

# %%
regions = ['North','South','West','East']
revenue = [3000,2000,1500,1000] 

plt.pie(revenue,labels=regions,autopct='%1.1f%%',colors=['gold','skyblue','lightgreen','coral'])
plt.title("Revenue Contribution by Region")
# Out:
# Text(0.5, 1.0, 'Revenue Contribution by Region')

# %% [markdown]
# ## Histograms

# %%
scores = [45,67,89,56,78,88,92,60,74,78,49,52,65,70,80,86,74,85,75]
plt.hist(scores,bins=5,color='purple',edgecolor='black')
plt.xlabel("Score Range")
plt.ylabel("No. of Students")
plt.title("Score Distribution of Strudents")
# Out:
# Text(0.5, 1.0, 'Score Distribution of Strudents')
